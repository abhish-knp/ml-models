# %% [markdown]
# # To Explore nba_api

# %%
# To import plyercareerstats to know about player career
from nba_api.stats.endpoints import playercareerstats

#to get player career data from player id
career = playercareerstats.PlayerCareerStats(player_id  = '203076')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203076   2012-13        00  1610612740               NOH        20.0
# 1     203076   2013-14        00  1610612740               NOP        21.0
# 2     203076   2014-15        00  1610612740               NOP        22.0
# 3     203076   2015-16        00  1610612740               NOP        23.0
# 4     203076   2016-17        00  1610612740               NOP        24.0
# 5     203076   2017-18        00  1610612740               NOP        25.0
# 6     203076   2018-19        00  1610612740               NOP        26.0
# 7     203076   2019-20        00  1610612747               LAL        27.0
# 8     203076   2020-21        00  1610612747               LAL        28.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  64  60  1846.0  349  ...   0.751   165   357  522   63   75  112   89  158
# ...

# %%
career.get_data_frames()[0].columns
# Out:
# Index(['PLAYER_ID', 'SEASON_ID', 'LEAGUE_ID', 'TEAM_ID', 'TEAM_ABBREVIATION',
#        'PLAYER_AGE', 'GP', 'GS', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A',
#        'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# These are column name of dataframe

# %% [markdown]
# <code>career = playercareerstats.PlayerCareerStats(player_id = '203076') </code> to get data from playercareerstats<br>
# <code>.get_data_frames()[0]</code> for getting data frame.

# %%
dir(playercareerstats)
# Out:
# ['Endpoint',
#  'LeagueIDNullable',
#  'NBAStatsHTTP',
#  'PerMode36',
#  'PlayerCareerStats',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__']

# %% [markdown]
# dir omit class/function and its attributes.<br>
# Can check dir: 'Endpoint','LeagueIDNullable','NBAStatsHTTP','PerMode36','PlayerCareerStats'

# %%
# To convert career_plyer class into dataframe

carrer_player = career.get_data_frames()[0]
carrer_player.head(3)
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203076   2012-13        00  1610612740               NOH        20.0
# 1     203076   2013-14        00  1610612740               NOP        21.0
# 2     203076   2014-15        00  1610612740               NOP        22.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  64  60  1846.0  349  ...   0.751   165   357  522   63   75  112   89  158
# 1  67  66  2358.0  522  ...   0.791   207   466  673  105   89  189  109  200
# 2  68  68  2455.0  642  ...   0.805   173   523  696  149  100  200   95  141
#
#     PTS
# 0   867
# 1  1394
# 2  1656
#
# [3 rows x 27 columns]

# %%
carrer_player.columns
# Out:
# Index(['PLAYER_ID', 'SEASON_ID', 'LEAGUE_ID', 'TEAM_ID', 'TEAM_ABBREVIATION',
#        'PLAYER_AGE', 'GP', 'GS', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A',
#        'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
carrer_player.describe()
# Out:
#        PLAYER_ID       TEAM_ID  PLAYER_AGE         GP         GS          MIN  \
# count        9.0  9.000000e+00    9.000000   9.000000   9.000000     9.000000
# mean    203076.0  1.610613e+09   24.000000  62.666667  62.111111  2155.666667
# std          0.0  3.086710e+00    2.738613  11.789826  11.762700   492.368003
# min     203076.0  1.610613e+09   20.000000  36.000000  36.000000  1162.000000
# 25%     203076.0  1.610613e+09   22.000000  61.000000  60.000000  1850.000000
# 50%     203076.0  1.610613e+09   24.000000  64.000000  62.000000  2164.000000
# 75%     203076.0  1.610613e+09   26.000000  68.000000  68.000000  2455.000000
# max     203076.0  1.610613e+09   28.000000  75.000000  75.000000  2727.000000
#
#               FGM          FGA    FG_PCT       FG3M  ...    FT_PCT  \
# count    9.000000     9.000000  9.000000   9.000000  ...  9.000000
# mean   556.111111  1082.111111  0.512556  31.000000  ...  0.790333
# ...

# %%
#imported basic python libraries

import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# To plot some of random visual graphs using matplot library

features=['SEASON_ID','TEAM_ID','TEAM_ABBREVIATION']
fig=plt.subplots(figsize=(10,15))
for i, j in enumerate(features):
    plt.subplot(4, 2, i+1)
    plt.subplots_adjust(hspace = 1.0)
    sns.countplot(x=j,data = carrer_player)
    plt.xticks(rotation=90)
    plt.title("Player 36 stats")

# %% [markdown]
# ## Teams Stats
# ### To get Team data

# %%
# Get data of teams of nba

from nba_api.stats.static import teams
def one_dict(list_dict):
    keys=list_dict[0].keys()
    out_dict={key:[] for key in keys}
    for dict_ in list_dict:
        for key, value in dict_.items():
            out_dict[key].append(value)
    return out_dict

# %% [markdown]
# one_dict() Function which converts dict into dataframe

# %%
from nba_api.stats.static import players

# %%
# Trying to fetch players record

nba_player = players.get_players()
one_dict(nba_player)
df_player = pd.DataFrame(nba_player)
df_player.head()
# Out:
#       id            full_name first_name     last_name  is_active
# 0  76001       Alaa Abdelnaby       Alaa     Abdelnaby      False
# 1  76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz      False
# 2  76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar      False
# 3     51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf      False
# 4   1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad      False

# %%
df_player.shape
# Out:
# (4501, 5)

# %% [markdown]
# ### To plot graph of active players in NBA

# %%
left_count=df_nba_players.groupby('is_active').count()
plt.bar(left_count.index.values, left_count['full_name'])
plt.xlabel('Players who are active in nba')
plt.ylabel('Frequency')
plt.show()

# %%
# To work with pickel file.
# how to unwrap pickel file and 
# How to prepare and update pickel file

# %%
import pandas as pd
file_name = "C:/Users/DellVostro/Desktop/jupyter_project/EDX/Python-basics-for-data-science/Revised_notebooks/Golden_State.pkl"
games = pd.read_pickle(file_name)
games.tail()
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 3233     21983  1610612744               GOS  Golden State Warriors
# 3234     21983  1610612744               GOS  Golden State Warriors
# 3235     21983  1610612744               GOS  Golden State Warriors
# 3236     21983  1610612744               GOS  Golden State Warriors
# 3237     21983  1610612744               GOS  Golden State Warriors
#
#          GAME_ID   GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  \
# 3233  0028300048  1983-11-05  GOS vs. NYK  W  238  102  ...   0.711  25.0
# 3234  0028300040  1983-11-03    GOS @ UTH  L  240  112  ...   0.880  27.0
# 3235  0028300029  1983-11-01    GOS @ KCK  L  240  114  ...   0.750  12.0
# 3236  0028300013  1983-10-29  GOS vs. POR  W  240   97  ...   0.744  12.0
# 3237  0028300004  1983-10-28    GOS @ SEA  W  240  110  ...   0.703  21.0
#
#       DREB   REB  AST   STL  BLK   TOV  PF  PLUS_MINUS
# 3233  18.0  43.0   20  16.0    4  17.0  26         NaN
# ...

# %%
games.shape
# Out:
# (3238, 28)

# %%
games.columns
# Out:
# Index(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS'],
#       dtype='object')

# %%
# 'TEAM_ID' is unique, means it is only one team data

games['TEAM_ID'].unique()
# Out:
# array([1610612744], dtype=int64)

# %%
games['WL'].unique()
# Out:
# array(['L', 'W', None], dtype=object)

# %%
# There are only Two Teams data in it

games['TEAM_ABBREVIATION'].unique()
# Out:
# array(['GSW', 'GOS'], dtype=object)

# %%
#  Possible match happened in between teams

games['MATCHUP'].unique()
# Out:
# array(['GSW vs. LAL', 'GSW @ DEN', 'GSW @ LAL', 'GSW vs. TOR',
#        'GSW vs. CHA', 'GSW vs. MIA', 'GSW @ SAC', 'GSW @ TOR',
#        'GSW @ POR', 'GSW vs. POR', 'GSW @ HOU', 'GSW vs. HOU',
#        'GSW @ LAC', 'GSW vs. LAC', 'GSW @ MEM', 'GSW @ NOP',
#        'GSW vs. CLE', 'GSW vs. DEN', 'GSW @ MIN', 'GSW vs. DET',
#        'GSW vs. DAL', 'GSW vs. IND', 'GSW @ SAS', 'GSW @ OKC',
#        'GSW vs. PHX', 'GSW vs. BOS', 'GSW @ PHI', 'GSW @ ORL',
#        'GSW @ MIA', 'GSW @ CHA', 'GSW vs. SAC', 'GSW vs. UTA',
#        'GSW @ PHX', 'GSW vs. SAS', 'GSW vs. PHI', 'GSW @ IND',
#        'GSW @ BOS', 'GSW @ WAS', 'GSW vs. NOP', 'GSW @ DAL',
#        'GSW vs. CHI', 'GSW vs. NYK', 'GSW @ UTA', 'GSW vs. MEM',
#        'GSW vs. MIN', 'GSW @ MIL', 'GSW @ CLE', 'GSW @ ATL', 'GSW @ DET',
#        'GSW vs. ORL', 'GSW vs. OKC', 'GSW vs. ATL', 'GSW vs. BKN',
#        'GSW vs. MIL', 'GSW @ CHI', 'GSW @ BKN', 'GSW @ NYK',
#        'GSW vs. WAS', 'GSW vs. NOH', 'GSW @ NOH', 'GSW vs. MAC',
# ...

# %% [markdown]
# ### Query search of PF >= 30

# %%
df_new = (games['PF'].values >= 30 )
df_new = games[df_new]
df_new.head()
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 28      42018  1610612744               GSW  Golden State Warriors
# 112     12018  1610612744               GSW  Golden State Warriors
# 113     12018  1610612744               GSW  Golden State Warriors
# 120     22018  1610612744               GSW  Golden State Warriors
# 229     12017  1610612744               GSW  Golden State Warriors
#
#         GAME_ID   GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  \
# 28   0041800142  2019-04-15  GSW vs. LAC  L  240  131  ...   0.889   7.0
# 112  0011800079  2018-10-12  GSW vs. LAL  L  241  105  ...   0.735  11.0
# 113  0011800065  2018-10-10    GSW @ LAL  L  241  113  ...   0.556  15.0
# 120  1521800026  2018-07-08    GSW @ HOU  L  200   81  ...   0.700  11.0
# 229  0011700044  2017-10-08    GSW @ MIN  W  240  142  ...   0.800   7.0
#
#      DREB   REB  AST   STL  BLK   TOV  PF  PLUS_MINUS
# 28   31.0  38.0   31  11.0    6  22.0  31        -4.0
# ...

# %%
df_new.shape
# Out:
# (311, 28)

# %% [markdown]
# ### To filter data based on conditions-
# #### Games between GSW vs TOR in home and away.

# %%
games_home=games [games ['MATCHUP']=='GSW vs. TOR']
games_away=games [games ['MATCHUP']=='GSW @ TOR']
games_away.tail(3)
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 1861     21999  1610612744               GSW  Golden State Warriors
# 2053     21997  1610612744               GSW  Golden State Warriors
# 2117     21996  1610612744               GSW  Golden State Warriors
#
#          GAME_ID   GAME_DATE    MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  \
# 1861  0029900911  2000-03-14  GSW @ TOR  L  240   78  ...   0.462  16.0  31.0
# 2053  0029700034  1997-11-04  GSW @ TOR  L  241   86  ...   0.517  23.0  35.0
# 2117  0029600277  1996-12-10  GSW @ TOR  W  239  101  ...   0.842  22.0  29.0
#
#        REB  AST  STL  BLK   TOV  PF  PLUS_MINUS
# 1861  47.0   20  4.0    9  12.0  25        -7.0
# 2053  58.0   26  4.0    3  25.0  24       -18.0
# 2117  51.0   15  8.0    4  18.0  18        10.0
#
# [3 rows x 28 columns]

# %%
games_home.shape
# Out:
# (26, 28)

# %%
# To count no of winning matchs

games_home.groupby('WL').count()
# Out:
#     SEASON_ID  TEAM_ID  TEAM_ABBREVIATION  TEAM_NAME  GAME_ID  GAME_DATE  \
# WL
# L           9        9                  9          9        9          9
# W          17       17                 17         17       17         17
#
#     MATCHUP  MIN  PTS  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# WL                          ...
# L         9    9    9    9  ...       9     9     9    9    9    9    9    9
# W        17   17   17   17  ...      17    17    17   17   17   17   17   17
#
#     PF  PLUS_MINUS
# WL
# L    9           9
# W   17          17
#
# [2 rows x 27 columns]

# %%
games_home.shape
# Out:
# (26, 28)

# %%
games_home.mean()['PLUS_MINUS']
# Out:
# 3.730769230769231

# %%
games_away.mean()['PLUS_MINUS']
# Out:
# -0.6071428571428571

# %% [markdown]
# ### Line plot of above filter data:

# %%
import matplotlib.pyplot as plt

ax = plt.subplot()
games_away.plot(x='GAME_DATE',y='PLUS_MINUS', ax=ax)
games_home.plot(x='GAME_DATE',y='PLUS_MINUS', ax=ax)
ax.legend(["away", "home"])
plt.show()

# %% [markdown]
# ### Basics and Package Structure:

# %%
# Getting Team and Player IDs
# get_teams returns a list of 30 dictionaries, each an NBA team.
nba_teams = teams.get_teams()
print('Number of teams fetched: {}'.format(len(nba_teams)))
# Top Three entries
nba_teams[:3]
# Out:
# Number of teams fetched: 30
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Atlanta',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970}]

# %% [markdown]
# Output is in form of dict, so we have to use the one_dict() function to convert into dataframe.

# %% [markdown]
# ### query search of nba_teams

# %%
spurs = [team for team in nba_teams
         if team['full_name'] == 'San Antonio Spurs'][0]
spurs
# Out:
# {'id': 1610612759,
#  'full_name': 'San Antonio Spurs',
#  'abbreviation': 'SAS',
#  'nickname': 'Spurs',
#  'city': 'San Antonio',
#  'state': 'Texas',
#  'year_founded': 1976}

# %% [markdown]
# ### Finding Games

# %%
nba_teams = teams.get_teams()
# Select the dictionary for the Celtics, which contains their team ID
celtics = [team for team in nba_teams if team['abbreviation'] == 'BOS'][0]
celtics_id = celtics['id']

# %%
celtics_id
# Out:
# 1610612738

# %% [markdown]
# ### Games of Celetics-

# %%
from nba_api.stats.endpoints import leaguegamefinder

# Query for games where the Celtics were playing
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=celtics_id)
# The first DataFrame of those returned is what we want.
games = gamefinder.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 0     22021  1610612738               BOS  Boston Celtics  1522100001
# 1     42020  1610612738               BOS  Boston Celtics  0042000115
# 2     42020  1610612738               BOS  Boston Celtics  0042000114
# 3     42020  1610612738               BOS  Boston Celtics  0042000113
# 4     42020  1610612738               BOS  Boston Celtics  0042000112
#
#     GAME_DATE      MATCHUP    WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2021-08-08    BOS @ ATL  None  200   74  ...   0.800     7    25   32   19
# 1  2021-06-01    BOS @ BKN     L  240  109  ...   0.783    13    31   44   18
# 2  2021-05-30  BOS vs. BKN     L  241  126  ...   0.905    11    23   34   24
# 3  2021-05-28  BOS vs. BKN     W  240  125  ...   0.826    13    33   46   21
# 4  2021-05-25    BOS @ BKN     L  239  108  ...   0.783    15    28   43   23
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    4    1    9  20         2.6
# ...

# %% [markdown]
# ### Total no. of games from 2015 to now

# %%
games.groupby(games.SEASON_ID.str[-4:])[['GAME_ID']].count().loc['2015':]
# Out:
#            GAME_ID
# SEASON_ID
# 2015           103
# 2016           115
# 2017           113
# 2018           101
# 2019           102
# 2020            80
# 2021             1

# %%
# filter to games in the 2017-18 Season

# Subset the games to when the last 4 digits of SEASON_ID were 2017.
games_1718 = games[games.SEASON_ID.str[-4:] == '2017']
games_1718.head(3)
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 284     42017  1610612738               BOS  Boston Celtics  0041700307
# 285     42017  1610612738               BOS  Boston Celtics  0041700306
# 286     42017  1610612738               BOS  Boston Celtics  0041700305
#
#       GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 284  2018-05-27  BOS vs. CLE  L  240   79  ...   0.737    11    31   42   18
# 285  2018-05-25    BOS @ CLE  L  241   99  ...   0.550     5    26   31   25
# 286  2018-05-23  BOS vs. CLE  W  240   96  ...   0.913     7    38   45   18
#
#      STL  BLK  TOV  PF  PLUS_MINUS
# 284    6    0    5  20        -8.0
# 285    5    2   13  18       -10.0
# 286   10    6    8  19        13.0
#
# [3 rows x 28 columns]

# %% [markdown]
# ### Filter to games against the Raptors

# %%
# Subset the games to where MATCHUP contains 'TOR'.
raps_games_1718 = games_1718[games_1718.MATCHUP.str.contains('TOR')]
raps_games_1718.head(3)
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 307     22017  1610612738               BOS  Boston Celtics  0021701171
# 309     22017  1610612738               BOS  Boston Celtics  0021701140
# 330     22017  1610612738               BOS  Boston Celtics  0021700798
#
#       GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 307  2018-04-04    BOS @ TOR  L  237   78  ...   0.893     8    35   43   10
# 309  2018-03-31  BOS vs. TOR  W  240  110  ...   0.852     8    33   41   19
# 330  2018-02-06    BOS @ TOR  L  240   91  ...   0.750     9    29   38   21
#
#      STL  BLK  TOV  PF  PLUS_MINUS
# 307    7    3   16  16       -18.0
# 309    6    3    5  23        11.0
# 330    3    3   17  19       -20.0
#
# [3 rows x 28 columns]

# %% [markdown]
# ### Sort by Game Date and select the Last Row

# %%
last_raps_game = raps_games_1718.sort_values('GAME_DATE').iloc[-1]
print(last_raps_game)
# Out:
# SEASON_ID                     22017
# TEAM_ID                  1610612738
# TEAM_ABBREVIATION               BOS
# TEAM_NAME            Boston Celtics
# GAME_ID                  0021701171
# GAME_DATE                2018-04-04
# MATCHUP                   BOS @ TOR
# WL                                L
# MIN                             237
# PTS                              78
# FGM                              25
# FGA                              75
# FG_PCT                        0.333
# FG3M                              3
# FG3A                             22
# FG3_PCT                       0.136
# FTM                              25
# FTA                              28
# FT_PCT                        0.893
# OREB                              8
# DREB                             35
# REB                              43
# AST                              10
# STL                               7
# BLK                               3
# TOV                              16
# ...

# %%
# Last game if raptors
game_id = last_raps_game.GAME_ID
game_id
# Out:
# '0021701171'

# %%
# Get **all** the games so we can filter to an individual GAME_ID
result = leaguegamefinder.LeagueGameFinder()
all_games = result.get_data_frames()[0]
# Find the game_id we want
full_game = all_games[all_games.GAME_ID == game_id]
full_game
# Out:
#       SEASON_ID     TEAM_ID TEAM_ABBREVIATION        TEAM_NAME     GAME_ID  \
# 14782     22017  1610612761               TOR  Toronto Raptors  0021701171
# 14786     22017  1610612738               BOS   Boston Celtics  0021701171
#
#         GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  \
# 14782  2018-04-04  TOR vs. BOS  W  240   96  ...   0.750    12    36   48
# 14786  2018-04-04    BOS @ TOR  L  237   78  ...   0.893     8    35   43
#
#        AST  STL  BLK  TOV  PF  PLUS_MINUS
# 14782   23   10    6   10  25        18.0
# 14786   10    7    3   16  16       -18.0
#
# [2 rows x 28 columns]

# %% [markdown]
# ### Play-by-play Data for a Given game:

# %%
from nba_api.stats.endpoints import playbyplayv2
pbp = playbyplayv2.PlayByPlayV2(game_id)
pbp = pbp.get_data_frames()[0]
pbp.head()
# Out:
#       GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0  0021701171         2            12                   0       1
# 1  0021701171         4            10                   0       1
# 2  0021701171         7             2                   1       1
# 3  0021701171         8             4                   0       1
# 4  0021701171         9             2                  86       1
#
#   WCTIMESTRING PCTIMESTRING                                   HOMEDESCRIPTION  \
# 0      8:11 PM        12:00                                              None
# 1      8:11 PM        12:00  Jump Ball Valanciunas vs. Baynes: Tip to Anunoby
# 2      8:11 PM        11:38                        MISS DeRozan 21' Jump Shot
# 3      8:11 PM        11:36                                              None
# 4      8:12 PM        11:21                                              None
#
#                   NEUTRALDESCRIPTION  \
# 0  Start of 1st Period (8:11 PM EST)
# ...
